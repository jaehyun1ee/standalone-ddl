# %% [markdown]
# <a href="https://colab.research.google.com/github/wenko99/Standalone_DDL/blob/master/Lec01/Lec1_Nearest_Neighbor_sk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Packages and Set Dataset

# %%
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()
iris_data = iris.data
iris_labels = iris.target

import pandas as pd

df = pd.DataFrame(iris_data)
df2 = pd.DataFrame(iris_labels)
df = pd.concat([df, df2], axis=1, sort=False)
df.columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Classes']

np.random.seed(7)
df = df.reindex(np.random.permutation(df.index))

iris_data = df.iloc[:, :4].values
iris_labels = df.iloc[:, 4].values

df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Classes
# 149          5.9         3.0          5.1         1.8        2
# 84           5.4         3.0          4.5         1.5        1
# 40           5.0         3.5          1.3         0.3        0
# 66           5.6         3.0          4.5         1.5        1
# 106          4.9         2.5          4.5         1.7        2
# 41           4.5         2.3          1.3         0.3        0
# 52           6.9         3.1          4.9         1.5        1
# 94           5.6         2.7          4.2         1.3        1
# 11           4.8         3.4          1.6         0.2        0
# 51           6.4         3.2          4.5         1.5        1
# 77           6.7         3.0          5.0         1.7        1
# 85           6.0         3.4          4.5         1.6        1
# 32           5.2         4.1          1.5         0.1        0
# 109          7.2         3.6          6.1         2.5        2
# 28           5.2         3.4          1.4         0.2        0
# 70           5.9         3.2          4.8         1.8        1
# 108          6.7         2.5          5.8         1.8        2
# 137          6.4         3.1          5.5         1.8        2
# 46           5.1         3.8          1.6         0.2        0
# 37           4.9         3.6          1.4         0.1        0
# 82           5.8         2.7          3.9         1.2        1
# 120          6.9         3.2          5.7         2.3        2
# 63           6.1         2.9          4.7         1.4        1
# 119          6.0         2.2          5.0         1.5        2
# 129          7.2         3.0          5.8         1.6        2
# 138          6.0         3.0          4.8         1.8        2
# 97           6.2         2.9          4.3         1.3        1
# 80           5.5         2.4          3.8         1.1        1
# 101          5.8         2.7          5.1         1.9        2
# 140          6.7         3.1          5.6         2.4        2
# ..           ...         ...          ...         ...      ...
# 34           4.9         3.1          1.5         0.2        0
# 64           5.6         2.9          3.6         1.3        1
# 61           5.9         3.0          4.2         1.5        1
# 123          6.3         2.7          4.9         1.8        2
# 112          6.8         3.0          5.5         2.1        2
# 53           5.5         2.3          4.0         1.3        1
# 133          6.3         2.8          5.1         1.5        2
# 24           4.8         3.4          1.9         0.2        0
# 56           6.3         3.3          4.7         1.6        1
# 69           5.6         2.5          3.9         1.1        1
# 44           5.1         3.8          1.9         0.4        0
# 19           5.1         3.8          1.5         0.3        0
# 6            4.6         3.4          1.4         0.3        0
# 55           5.7         2.8          4.5         1.3        1
# 75           6.6         3.0          4.4         1.4        1
# 0            5.1         3.5          1.4         0.2        0
# 135          7.7         3.0          6.1         2.3        2
# 127          6.1         3.0          4.9         1.8        2
# 68           6.2         2.2          4.5         1.5        1
# 136          6.3         3.4          5.6         2.4        2
# 42           4.4         3.2          1.3         0.2        0
# 110          6.5         3.2          5.1         2.0        2
# 89           5.5         2.5          4.0         1.3        1
# 72           6.3         2.5          4.9         1.5        1
# 23           5.1         3.3          1.7         0.5        0
# 142          5.8         2.7          5.1         1.9        2
# 92           5.8         2.6          4.0         1.2        1
# 103          6.3         2.9          5.6         1.8        2
# 67           5.8         2.7          4.1         1.0        1
# 25           5.0         3.0          1.6         0.2        0
#
# [150 rows x 5 columns]

# %% [markdown]
# train data/labels : machine의 dataset입니다.
#
# test data/labels : machine의 성능을 테스트할 dataset입니다.

# %%
n_train_data = 130

train_data = iris_data[ : n_train_data]
train_labels = iris_labels[ : n_train_data]
test_data = iris_data[n_train_data : ]
test_labels = iris_labels[n_train_data : ]

# %% [markdown]
# ## Define L2 distance function

# %%
def dist_l2(array1, array2):
    
    '''
    Input : 2 * 1D-array
    
    Output : distance between two arrays
    
    Write your code for L2 distance here
    
    '''

# %% [markdown]
# #Test Model

# %%
acc = 0

'''
acc : Accuracy of the model

Write your code calculating accuracy using test set

'''

print("Accuracy of Nearest Neighbor : {:.2%}".format(acc))
# Out:
# Accuracy of Nearest Neighbor : 0.00%
