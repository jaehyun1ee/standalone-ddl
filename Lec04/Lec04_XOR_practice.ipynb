# %% [markdown]
# <a href="https://colab.research.google.com/github/wenko99/Standalone_DDL/blob/master/Lec04/Lec04_XOR_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

print(tf.__version__)
print(tf.keras.__version__)
# Out:
# 1.14.0
# 2.2.4-tf

# %% [markdown]
# ##Create Data

# %%
xx, yy = np.meshgrid(np.linspace(-3, 3, 50),
                     np.linspace(-3, 3, 50))
rng = np.random.RandomState(0)
X = rng.randn(500, 2)
Y = np.logical_xor(X[:, 0] > 0, X[:, 1] > 0)

# %% [markdown]
# ##Data Visualization

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(1, 1, 1)
ax.scatter(X[:, 0], X[:, 1], s=30, c=Y, cmap=plt.cm.bwr,
                edgecolors=(0, 0, 0))

major_ticks = np.arange(-3, 3, 1)
minor_ticks = np.arange(-3, 3, 0.25)

ax.set_xticks(major_ticks)
ax.set_xticks(minor_ticks, minor=True)
ax.set_yticks(major_ticks)
ax.set_yticks(minor_ticks, minor=True)

ax.grid(which='minor', alpha=0.2)
ax.grid(which='major', alpha=0.5)
plt.show()

# %% [markdown]
# ##Data Preprocessing
#
# - train_data :  shape = $(400, 2)$, dtype = float64
# - train_labels : shape =  $(400,)$, dtype = int64
# - val_data :  shape = $(50, 2)$, dtype = float64
# - val_labels : shape =  $(50,)$, dtype = int64
# - test_data :  shape = $(50, 2)$, dtype = float64
# - test_labels : shape =  $(50,)$, dtype = int64

# %%
Y = Y.astype(int)

# %%
train_data = X[:400]
train_labels = Y[:400]
val_data = X[400:450]
val_labels = Y[400:450]
test_data = X[450:]
test_labels = X[450:]

# %% [markdown]
# #Playground
#
# Keras를 이용하여 XOR문제를 해결해보세요!
#
# hint1: 마지막 layer로 softmax를 사용한다면 2차원으로 출력하여야 할 것입니다.
#
# hint2: binary_crossentropy 를 loss function으로 사용하여 compile 해보는 것은 어떨까요?
